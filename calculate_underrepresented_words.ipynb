# %%
import pandas as pd
import re

# %%
# read frequncy lists from disk (created using make_frequency_lists.ipynb)
aftenposten_words = pd.read_csv("AP_words.csv").set_index("Unnamed: 0")
klassekampen_words = pd.read_csv("KK_words.csv").set_index("Unnamed: 0")
dagsavisen_words = pd.read_csv("DA_words.csv").set_index("Unnamed: 0")

# %%
# inspect one freqlist
aftenposten_words
# Out:
#                         freq       relfreq
# Unnamed: 0
# .                    4142764  4.898341e-02
# ,                    2754528  3.256912e-02
# :                    1675850  1.981499e-02
# i                    1627454  1.924277e-02
# og                   1370069  1.619949e-02
# ...                      ...           ...
# Teisbæk                    1  1.182385e-08
# Parafili                   1  1.182385e-08
# KJBHHBR                    1  1.182385e-08
# bortfortolke               1  1.182385e-08
# Tilleggsutredningen        1  1.182385e-08
#
# [1613092 rows x 2 columns]

# %%
# join frequency lists of Aftenposten and Dagsavisen
merged = aftenposten_words.merge(dagsavisen_words, left_index=True, right_index=True, suffixes=["_AP", "_DA"])

# %%
merged
# Out:
#                    freq_AP    relfreq_AP  freq_DA    relfreq_DA
# Unnamed: 0
# .                  4142764  4.898341e-02  2578023  4.500726e-02
# ,                  2754528  3.256912e-02  1892745  3.304364e-02
# :                  1675850  1.981499e-02  1178465  2.057370e-02
# i                  1627454  1.924277e-02  1117636  1.951175e-02
# og                 1370069  1.619949e-02   941387  1.643478e-02
# ...                    ...           ...      ...           ...
# livsstilsveileder        1  1.182385e-08        1  1.745805e-08
# ungdomskjærester         1  1.182385e-08        1  1.745805e-08
# Ambi                     1  1.182385e-08        1  1.745805e-08
# rhard                    1  1.182385e-08        1  1.745805e-08
# bjørnetjenester          1  1.182385e-08        1  1.745805e-08
#
# [518184 rows x 4 columns]

# %%
# ignore words with casing and non-word characters
def is_valid_index(idx):
    return isinstance(idx, str) and idx.islower() and bool(re.match(r'^\w+$', idx))

# %%
filtered_merged = merged[merged.index.map(is_valid_index)]

# %%
filtered_merged
# Out:
#                    freq_AP    relfreq_AP  freq_DA    relfreq_DA
# Unnamed: 0
# i                  1627454  1.924277e-02  1117636  1.951175e-02
# og                 1370069  1.619949e-02   941387  1.643478e-02
# er                  950171  1.123468e-02   661978  1.155685e-02
# å                   852758  1.008288e-02   555856  9.704163e-03
# på                  755178  8.929109e-03   523656  9.142014e-03
# ...                    ...           ...      ...           ...
# defintivt                1  1.182385e-08        1  1.745805e-08
# livsstilsveileder        1  1.182385e-08        1  1.745805e-08
# ungdomskjærester         1  1.182385e-08        1  1.745805e-08
# rhard                    1  1.182385e-08        1  1.745805e-08
# bjørnetjenester          1  1.182385e-08        1  1.745805e-08
#
# [230710 rows x 4 columns]

# %%
# divide relative frequencies
filtered_merged["underrep_DA"] = filtered_merged["relfreq_AP"] / filtered_merged["relfreq_DA"]
filtered_merged["underrep_AP"] = filtered_merged["relfreq_DA"] / filtered_merged["relfreq_AP"]
# Out:
# /tmp/ipykernel_10423/747418208.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_merged["underrep_DA"] = filtered_merged["relfreq_AP"] / filtered_merged["relfreq_DA"]
# /tmp/ipykernel_10423/747418208.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_merged["underrep_AP"] = filtered_merged["relfreq_DA"] / filtered_merged["relfreq_AP"]

# %%
# look at underrepresented words in Aftenposten relative to Dagsavisen (ten times more common
filtered_merged[filtered_merged["underrep_AP"] > 10].sort_values(by="freq_DA", ascending=False).head(50)
# Out:
#                      freq_AP    relfreq_AP  freq_DA  relfreq_DA  underrep_DA  \
# Unnamed: 0
# lør                     2601  3.075383e-05    46379    0.000810     0.037982
# fre                     2526  2.986704e-05    43969    0.000768     0.038909
# søn                     2352  2.780969e-05    41751    0.000729     0.038153
# tors                     928  1.097253e-05    38212    0.000667     0.016448
# ons                      977  1.155190e-05    33139    0.000579     0.019967
# tirs                     315  3.724512e-06    32981    0.000576     0.006469
# fram                    1680  1.986406e-05    22814    0.000398     0.049874
# tida                     261  3.086024e-06     5724    0.000100     0.030882
# uka                      343  4.055580e-06     5661    0.000099     0.041036
# sju                      614  7.259842e-06     4660    0.000081     0.089237
# boka                     259  3.062376e-06     3828    0.000067     0.045824
# framover                 123  1.454333e-06     3118    0.000054     0.026717
# tilsvar                  202  2.388417e-06     3046    0.000053     0.044914
# verken                   189  2.234707e-06     2849    0.000050     0.044930
# klagemotparten             8  9.459078e-08     2574    0.000045     0.002105
# innleveringsfrist          2  2.364769e-08     2071    0.000036     0.000654
# dagsavisen                32  3.783631e-07     2023    0.000035     0.010713
# nyheder                   40  4.729539e-07     1993    0.000035     0.013593
# flor                      35  4.138347e-07     1868    0.000033     0.012690
# framtida                 111  1.312447e-06     1747    0.000030     0.043032
# odds                     246  2.908666e-06     1737    0.000030     0.095918
# forliksklage               4  4.729539e-08     1688    0.000029     0.001605
# esset                     93  1.099618e-06     1660    0.000029     0.037944
# gruppa                    78  9.222601e-07     1659    0.000029     0.031843
# klagerens                  7  8.276693e-08     1651    0.000029     0.002872
# klokka                   182  2.151940e-06     1582    0.000028     0.077916
# framtid                  162  1.915463e-06     1528    0.000027     0.071805
# arbeiderbevegelsens       31  3.665393e-07     1375    0.000024     0.015269
# nyhetsredaktør           122  1.442509e-06     1302    0.000023     0.063462
# spillefører               52  6.148401e-07     1258    0.000022     0.027995
# forkynt                   84  9.932032e-07     1244    0.000022     0.045732
# spilleprøve                6  7.094308e-08     1229    0.000021     0.003306
# oppholdssted              71  8.394932e-07     1162    0.000020     0.041382
# domstolloven              47  5.557208e-07     1126    0.000020     0.028270
# kinoen                    86  1.016851e-06     1031    0.000018     0.056494
# avisa                     90  1.064146e-06     1013    0.000018     0.060172
# skadd                    103  1.217856e-06     1011    0.000018     0.069000
# framstår                  26  3.074200e-07     1009    0.000018     0.017452
# arbeidstakere             66  7.803739e-07      982    0.000017     0.045519
# reserve                  132  1.560748e-06      976    0.000017     0.091598
# pålegges                 133  1.572572e-06      953    0.000017     0.094520
# lista                     50  5.911924e-07      950    0.000017     0.035646
# avsagt                   115  1.359742e-06      945    0.000016     0.082419
# reservasjon              138  1.631691e-06      942    0.000016     0.099218
# fraværsdom                11  1.300623e-07      909    0.000016     0.008196
# rettsstedet               28  3.310677e-07      903    0.000016     0.021001
# anmodning                 86  1.016851e-06      889    0.000016     0.065518
# forliksrådet              13  1.537100e-07      866    0.000015     0.010167
# filmomtaler               87  1.028675e-06      852    0.000015     0.069158
# forliksrådets              2  2.364769e-08      843    0.000015     0.001607
#
#                      underrep_AP
# Unnamed: 0
# lør                    26.328008
# fre                    25.701011
# søn                    26.209970
# tors                   60.797925
# ons                    50.082016
# tirs                  154.593145
# fram                   20.050681
# tida                   32.381435
# uka                    24.368904
# sju                    11.206101
# boka                   21.822733
# framover               37.428978
# tilsvar                22.264631
# verken                 22.257051
# klagemotparten        475.067721
# innleveringsfrist    1528.928129
# dagsavisen             93.343240
# nyheder                73.567208
# flor                   78.803552
# framtida               23.238436
# odds                   10.425615
# forliksklage          623.088045
# esset                  26.354945
# gruppa                 31.404273
# klagerens             348.245891
# klokka                 12.834296
# framtid                13.926607
# arbeiderbevegelsens    65.490450
# nyhetsredaktør         15.757529
# spillefører            35.720232
# forkynt                21.866439
# spilleprøve           302.438865
# oppholdssted           24.164886
# domstolloven           35.373457
# kinoen                 17.700975
# avisa                  16.618962
# skadd                  14.492753
# framstår               57.300022
# arbeidstakere          21.968708
# reserve                10.917240
# pålegges               10.579819
# lista                  28.053727
# avsagt                 12.133076
# reservasjon            10.078799
# fraværsdom            122.013579
# rettsstedet            47.617511
# anmodning              15.263013
# forliksrådet           98.358412
# filmomtaler            14.459634
# forliksrådets         622.349789

# %%
# look at underrepresented words in Dagsavisen relative to Aftenposten (ten times more common
filtered_merged[filtered_merged["underrep_DA"] > 10].sort_values(by="freq_AP", ascending=False).head(50)
# Out:
#              freq_AP  relfreq_AP  freq_DA    relfreq_DA  underrep_DA  \
# Unnamed: 0
# skyet          36626    0.000433       15  2.618708e-07  1653.717280
# vind           15334    0.000181      752  1.312845e-05    13.810222
# stoff           8000    0.000095      264  4.608926e-06    20.523390
# bris            7500    0.000089       69  1.204606e-06    73.616507
# veil            6069    0.000072      154  2.688540e-06    26.690668
# ili             5863    0.000069      252  4.399429e-06    15.757321
# lit             5805    0.000069      306  5.342164e-06    12.848246
# plussgrader     4399    0.000052       57  9.951090e-07    52.268753
# kvm             4276    0.000051      123  2.147340e-06    23.544833
# hverken         3878    0.000046      180  3.142449e-06    14.591446
# m²              3475    0.000041      178  3.107533e-06    13.222021
# kapell          3173    0.000038      160  2.793288e-06    13.431148
# kuling          3135    0.000037       55  9.601928e-07    38.604496
# x16             3051    0.000036        3  5.237416e-08   688.785483
# sovnet          3046    0.000036      191  3.334488e-06    10.800891
# llit            2860    0.000034        2  3.491610e-08   968.498762
# nekrologer      2787    0.000033        6  1.047483e-07   314.592780
# quiz            2549    0.000030      122  2.129882e-06    14.150541
# honorert        2354    0.000028        6  1.047483e-07   265.716327
# omv             2343    0.000028       39  6.808640e-07    40.688410
# lli             2229    0.000026      135  2.356837e-06    11.182511
# x17             2195    0.000026        2  3.491610e-08   743.305868
# roms            2175    0.000026       57  9.951090e-07    25.843268
# oppholdsvær     2060    0.000024       22  3.840771e-07    63.417274
# gavekort        2042    0.000024       94  1.641057e-06    14.712650
# ct              1946    0.000023       42  7.332382e-07    31.380263
# bopel           1894    0.000022       37  6.459479e-07    34.668997
# felter          1894    0.000022       40  6.983221e-07    32.068823
# tdøf            1832    0.000022       14  2.444127e-07    88.625861
# loddrette       1820    0.000022        8  1.396644e-07   154.079348
# boksene         1815    0.000021       52  9.078187e-07    23.639393
# snøbyger        1804    0.000021       16  2.793288e-07    76.362402
# radene          1753    0.000021        6  1.047483e-07   197.876262
# sludd           1751    0.000021       41  7.157801e-07    28.924464
# feltene         1724    0.000020       57  9.951090e-07    20.484503
# pip             1684    0.000020       28  4.888255e-07    40.733065
# megler          1668    0.000020       68  1.187148e-06    16.613080
# svigermor       1660    0.000020       95  1.658515e-06    11.834435
# nekrolog        1649    0.000019       21  3.666191e-07    53.181967
# årgang          1629    0.000019       79  1.379186e-06    13.965517
# kundesenter     1572    0.000019       19  3.317030e-07    56.035335
# vannrette       1475    0.000017        2  3.491610e-08   499.487998
# publisering     1442    0.000017       64  1.117315e-06    15.259782
# ffa             1404    0.000017       60  1.047483e-06    15.848162
# hindring        1391    0.000016       86  1.501392e-06    10.954479
# redigere        1341    0.000016       28  4.888255e-07    32.436485
# forkorte        1320    0.000016       41  7.157801e-07    21.804850
# forbeholder     1312    0.000016       45  7.856123e-07    19.746237
# kjært           1308    0.000015       79  1.379186e-06    11.213564
# presseskikk     1294    0.000015       30  5.237416e-07    29.212993
#
#              underrep_AP
# Unnamed: 0
# skyet           0.000605
# vind            0.072410
# stoff           0.048725
# bris            0.013584
# veil            0.037466
# ili             0.063463
# lit             0.077832
# plussgrader     0.019132
# kvm             0.042472
# hverken         0.068533
# m²              0.075631
# kapell          0.074454
# kuling          0.025904
# x16             0.001452
# sovnet          0.092585
# llit            0.001033
# nekrologer      0.003179
# quiz            0.070669
# honorert        0.003763
# omv             0.024577
# lli             0.089425
# x17             0.001345
# roms            0.038695
# oppholdsvær     0.015769
# gavekort        0.067969
# ct              0.031867
# bopel           0.028844
# felter          0.031183
# tdøf            0.011283
# loddrette       0.006490
# boksene         0.042302
# snøbyger        0.013095
# radene          0.005054
# sludd           0.034573
# feltene         0.048817
# pip             0.024550
# megler          0.060194
# svigermor       0.084499
# nekrolog        0.018803
# årgang          0.071605
# kundesenter     0.017846
# vannrette       0.002002
# publisering     0.065532
# ffa             0.063099
# hindring        0.091287
# redigere        0.030829
# forkorte        0.045861
# forbeholder     0.050643
# kjært           0.089178
# presseskikk     0.034231
